# %%
# import
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
#from sklearn.datasets import load_wine

# prep dataframe
data = pd.read_csv('DelinquentBusinessLicenses.csv', usecols=[1, 6, 7, 8, 9, 11, 12, 13, 14, 16, 17, 18, 19, 20, 21, 23, 24, 25])

# %%
data.columns
# Out:
# Index(['FULL NAME', 'PROCESSED DATE', 'START DATE', 'EXPIRE DATE',
#        'INACTIVE DATE', 'MILESTONE DATE', 'MILESTONE', 'PROPERTY TYPE',
#        'SITE LOCATION', 'COMPANY TYPE', '#EMPLOYEES', '#VEHICLES', '#STANDS',
#        '#SEATS', '#UNITS', 'COUNCIL DISTRICT', 'BID AREA',
#        'APPLICATION DESCRIPTION'],
#       dtype='object')

# %%
# prep dataframe

df = pd.DataFrame(
    data=data["START DATE"],
    columns=data["COMPANY TYPE"]
)
df["#EMPLOYEES"] = data["#EMPLOYEES"]

# inspect df
df.head()
# Out:
# COMPANY TYPE CORP CORP CORP TRUST CORP PARTNER PARTNER SOLE SOLE SOLE  ...  \
# 0             NaN  NaN  NaN   NaN  NaN     NaN     NaN  NaN  NaN  NaN  ...
# 1             NaN  NaN  NaN   NaN  NaN     NaN     NaN  NaN  NaN  NaN  ...
# 2             NaN  NaN  NaN   NaN  NaN     NaN     NaN  NaN  NaN  NaN  ...
# 3             NaN  NaN  NaN   NaN  NaN     NaN     NaN  NaN  NaN  NaN  ...
# 4             NaN  NaN  NaN   NaN  NaN     NaN     NaN  NaN  NaN  NaN  ...
#
# COMPANY TYPE  LLC SOLE  LLC CORP  NaN  LLC SOLE SOLE CORP #EMPLOYEES
# 0             NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN          2
# 1             NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN          0
# 2             NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN          0
# 3             NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN          0
# 4             NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN          1
#
# [5 rows x 557 columns]

# %%
classes, counts = np.unique(
    data["PARTNER"],
    return_counts=True
)

# actual plot
for (cls, cnt) in zip(classes, counts):
    plt.bar(
        x=cls,
        height=cnt,
        label="COMPANY TYPE {cls}".format(**locals())
    )
plt.legend(loc=0)
plt.xticks([1, 2, 3])
plt.title("Count by COMPANY TYPE");
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PARTNER'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-1022d64347b1> in <module>
#       1 classes, counts = np.unique(
# ...
