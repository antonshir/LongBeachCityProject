# %%
# Andre Barajas
#Long beach Small Business Delqinquency 
#import libraries
# install ggplot in terminal: conda install -c conda-forge ggplot
# %matplotlib inline
from ggplot import *
import pandas as pd
import numpy as np
import scipy.stats

# %%
import matplotlib
import matplotlib.pyplot as pp

import pandas.plotting

from IPython import display
from ipywidgets import interact, widgets

# %%
import re
import mailbox
import csv

# %%
dbc = pd.read_csv('Delinquent Business Licenses(1).csv',usecols=[1,2,6,7,8,15,16,17,22])

# %%
dbc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 556 entries, 0 to 555
# Data columns (total 9 columns):
# FULL NAME           556 non-null object
# DBA NAME            316 non-null object
# PROCESSED DATE      556 non-null object
# START DATE          556 non-null object
# EXPIRE DATE         533 non-null object
# ZIP                 556 non-null int64
# COMPANY TYPE        551 non-null object
# #EMPLOYEES          556 non-null int64
# TYPE OF BUSINESS    556 non-null object
# dtypes: int64(2), object(7)
# memory usage: 39.2+ KB

# %%
len(dbc)
# Out:
# 556

# %%
dbc.columns
# Out:
# Index(['FULL NAME', 'DBA NAME', 'PROCESSED DATE', 'START DATE', 'EXPIRE DATE',
#        'ZIP', 'COMPANY TYPE', '#EMPLOYEES', 'TYPE OF BUSINESS'],
#       dtype='object')

# %%
# build a quick plot (qplot)
qplot(x='#EMPLOYEES',data=dbc)
# Out:
# <ggplot: (8760666310748)>

# %%
qplot(x='TYPE OF BUSINESS',y='#EMPLOYEES', data=dbc, geom='bar')
# Out:
# <ggplot: (8760665526504)>

# %%
qplot(x='ZIP',y='#EMPLOYEES', data=dbc, geom='bar')
# Out:
# <ggplot: (-9223363276189757447)>

# %%
qplot(x='ZIP',y='TYPE OF BUSINESS', data=dbc, geom='jitter', color='#EMPLOYEES')
# Out:
# <ggplot: (-9223363276229152582)>
