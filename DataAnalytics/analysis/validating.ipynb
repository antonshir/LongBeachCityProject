# %%
import pandas as pd 
from textblob import TextBlob

oo = pd.read_csv('./yelp_scrape_result.csv')

oo = oo.drop(["Unnamed: 5", "Unnamed: 6", "Unnamed: 7", "Unnamed: 8", "Unnamed: 9", "Unnamed: 10", "Unnamed: 11"], axis=1)
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66973 entries, 0 to 66972
# Data columns (total 5 columns):
# review_id      66973 non-null object
# business_id    66973 non-null object
# rating         66973 non-null int64
# date           66973 non-null object
# review         66973 non-null object
# dtypes: int64(1), object(4)
# memory usage: 2.6+ MB

# %%
u = oo.business_id.unique()

for businessid in u:
    print(businessid)
# Out:
# 2c-WVw1SiBtqP2yT_r5J7Q
# vRwwkBsXPfa080sq8sa2Lg
# u9SZwMaC0ZwOnT-1l-ulVQ
# rgVZNk2EHF9UMc9CSjuMzg
# __9foSAQukY6VV1RwrYF_Q
# 7-Dy3UcD5xpSz4J6ETSpKQ
# mZVsJazL77EVx-prGqFMMQ
# plNxK0l8a0zxWn1q8EDLqQ
# i6Bgc-qaHqOTQCJgN7FtTw
# e74o62cT9l9FrDkz7V1Fsw
# ylEd8lcSF4XCxqxrzCg8tQ
# Vruqj8YnwKQoOM6NsDTzWA
# quiqroe8KCUt6qP7VGU4Iw
# WrK1o9uBeoG_iEqBTBMA1g
# sykREDj3ZeFyOhXUtT6BYA
# 6bxCRDfSJj0-_1d6lzd_4g
# 9Smq4ccR-6jTZItEmeG6mg
# Ql8BAOanPPQLQx8qd-KbeQ
# D3F-AH2ACYfSwTaTzBWiGA
# 0fvCXc192HrKDZB4Odg8ZA
# FnF7TyiIjIuTUOCktrY1og
# cplY3vlwYOVY_xWRlEakEA
# sPpGS6oTsRisTLS9-Tseow
# Ag2cJ9bqJ4ZP32-hyG7ckw
# mQ0li5UvWXagXKdeP5JKiQ
# 86xDJaGvLCfqG2u0_XNvYQ
# zQMcmUPUrjhlhW3yPRAE5A
# mLBWm7-oAIBzryElArjn-Q
# zhr2xLy_WOd5UT2TTRfm-A
# l-SoGUptKpajVSOEBVgUxA
# JOzhlQi1SBHIceMzm7RY6g
# MoKsqzCLi3b9GmJA_vzOWA
# 3wYTQsjrlU4k4SJsWf9RXA
# EKkMZz-ueANYbA9KnStdYw
# blw75-gWHxM9vB7kJ5ErzQ
# YQd53dJ4kcTrxZUFT4vKFA
# eY7VWeX8sH8qbMO3OGCOXQ
# RNLH9PkCHwNfwLypxWFU9w
# jLLFjdpL6zrGKxG10xGm2A
# rxsneJ6NiZeug2-dB0S5mw
# ...

# %%
df0= pd.DataFrame(oo)

for group_ky, group_val in oo.groupby('business_id'):
    #print(group_ky)
    #print(group_val)
    group_val.loc['polarity'] = group_val.apply(lambda x: TextBlob(x['review']).sentiment.polarity, axis=1)
    group_val.loc['subjectivity'] = group_val.apply(lambda x: TextBlob(x['review']).sentiment.subjectivity, axis=1)
#for index, row in df_reviews.iterrows():
 #   print(row)
  #  sentiment = TextBlob(row[''])
     #print each sen

print(group_ky)
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-689676a0d9b1> in <module>
#       5     #print(group_val)
# ...

# %%
oo
# Out:
#                                       review_id             business_id  \
# 0      2c-WVw1SiBtqP2yT_r5J7QWecameher6/16/2019  2c-WVw1SiBtqP2yT_r5J7Q
# 1      2c-WVw1SiBtqP2yT_r5J7QHeyy'all!8/19/2019  2c-WVw1SiBtqP2yT_r5J7Q
# 2      2c-WVw1SiBtqP2yT_r5J7QThankyouJ10/3/2019  2c-WVw1SiBtqP2yT_r5J7Q
# 3       2c-WVw1SiBtqP2yT_r5J7QThankyouM7/1/2019  2c-WVw1SiBtqP2yT_r5J7Q
# 4      2c-WVw1SiBtqP2yT_r5J7QLovethefo10/4/2019  2c-WVw1SiBtqP2yT_r5J7Q
# 5      2c-WVw1SiBtqP2yT_r5J7QCustomers8/11/2019  2c-WVw1SiBtqP2yT_r5J7Q
# 6      vRwwkBsXPfa080sq8sa2LgNowthisis9/19/2019  vRwwkBsXPfa080sq8sa2Lg
# 7      vRwwkBsXPfa080sq8sa2LgMetupwith9/24/2019  vRwwkBsXPfa080sq8sa2Lg
# 8       vRwwkBsXPfa080sq8sa2LgSendingal8/2/2019  vRwwkBsXPfa080sq8sa2Lg
# 9      vRwwkBsXPfa080sq8sa2LgLobsterbi6/28/2019  vRwwkBsXPfa080sq8sa2Lg
# 10     vRwwkBsXPfa080sq8sa2LgThefoodis5/18/2019  vRwwkBsXPfa080sq8sa2Lg
# 11     vRwwkBsXPfa080sq8sa2LgHadtherot7/26/2019  vRwwkBsXPfa080sq8sa2Lg
# ...

# %%
oo.shape
# Out:
# (66973, 12)

# %%
oo.tail()
# Out:
#                                       review_id             business_id  \
# 66968  rmM1atICUsN53PqonEYtpwThisplace3/17/2019  rmM1atICUsN53PqonEYtpw
# 66969  rmM1atICUsN53PqonEYtpwWorstwing5/14/2019  rmM1atICUsN53PqonEYtpw
# 66970   rmM1atICUsN53PqonEYtpwIusetolov2/8/2019  rmM1atICUsN53PqonEYtpw
# 66971   rmM1atICUsN53PqonEYtpwThepizzaw2/1/2019  rmM1atICUsN53PqonEYtpw
# 66972  SD2g7U1DzXX_PUaalMIlfQSooifindt7/27/2019  SD2g7U1DzXX_PUaalMIlfQ
#
#        rating       date                                             review  \
# 66968       1  3/17/2019  This place is horrible!!! Food quality and tas...
# 66969       1  5/14/2019  Worst wings ever!!! Super disappointing! The s...
# 66970       1   2/8/2019  I use to love their pizza until I found hairs ...
# 66971       1   2/1/2019  The pizza was late, cold, and the order was wr...
# 66972       1  7/27/2019  Soo i find this place on yelp and so far i can...
#
#       Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# ...

# %%
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66973 entries, 0 to 66972
# Data columns (total 12 columns):
# review_id      66973 non-null object
# business_id    66973 non-null object
# rating         66973 non-null int64
# date           66973 non-null object
# review         66973 non-null object
# Unnamed: 5     183 non-null object
# Unnamed: 6     22 non-null object
# Unnamed: 7     4 non-null object
# Unnamed: 8     2 non-null object
# Unnamed: 9     1 non-null object
# Unnamed: 10    1 non-null object
# Unnamed: 11    1 non-null object
# dtypes: int64(1), object(11)
# memory usage: 6.1+ MB

# %%
oo.business_id.value_counts(normalize=False, sort=False, ascending=False, bins=None, dropna=True)
# Out:
# HriHc9Eji4O2tnQw9ibbQQ     5
# CSpFe7xCWzI4r_L9A6pg4w     7
# 92ZpeWsBLCCogDlqBUJ1vA     1
# PwW5td_xZLHg-ytVIkc7Iw     1
# ZLeO5Fibo_KBkxIiBWDjwQ     5
# smL3uy9We3UUZZRiYqUhwQ     4
# ojWO3YdnYeJecw_2GFZOKg     6
# 9hw7WhXPaJSAoPvy80YtJw     1
# wHZqPJEytb2IV2WELgFOeg     4
# 01jmi7k3izMl3z__pSM8tA    49
# YUBs-Ymb_C1Vuaqn9mRFSw     5
# 3h4nu9F0LukT9ZrLqX1FLA     2
# pRd5gNKY8N6t0Sp5v4RqAQ     2
# R2NsuFhHYjglRG0cgsLxUw     3
# f2kvYHrSxPKtWrzst0qeCQ     1
# 711qI_j5Ba0v7u0ZWac7gQ     3
# zqiER16zZy5So4gwsfIysg    34
# uu6623FETcr9qVYNb1yQhw     2
# YWr-lzdZ5nQp_XWieQbTRA     8
# j5lqRt8pr-k2F1v3ikai8g    45
# KMHWXrk9bcWUP7nX93aj3g     3
# 9f9lh4LSjTGve4SwFGl1uQ     1
# Hl-53WzVp3b50JejWaZEVA     2
# 8q2zstJeQKdNJ57ryN177A    12
# LWGL3WezcuW59rttzSFJqQ     1
# pd7jEb-MnisbUlCuncB5IA     5
# zdsv62ndpuZSvXzUNKdo8g     1
# LicHUiCHCZlJNygt3wppOA     4
# gbuBKV0YHDotps0Ymgy33Q    13
# Znit-VUmAdbF07seXcgZ0w     5
#                           ..
# 3D07a6IzDHNiz9AloeozPA     2
# ...

# %%
df = oo[oo.business_id == 'EuQM5S_MwhqQZPGa4HpMAA']

# %%
df
# Out:
#                                       review_id             business_id  \
# 32100  EuQM5S_MwhqQZPGa4HpMAA$4.50fora6/14/2019  EuQM5S_MwhqQZPGa4HpMAA
# 32101  EuQM5S_MwhqQZPGa4HpMAAGreatserv9/14/2019  EuQM5S_MwhqQZPGa4HpMAA
# 32102   EuQM5S_MwhqQZPGa4HpMAARiverasTa3/5/2019  EuQM5S_MwhqQZPGa4HpMAA
# 32103   EuQM5S_MwhqQZPGa4HpMAABestMexic1/8/2019  EuQM5S_MwhqQZPGa4HpMAA
# 32104  EuQM5S_MwhqQZPGa4HpMAABeencomin1/31/2019  EuQM5S_MwhqQZPGa4HpMAA
# 32105  EuQM5S_MwhqQZPGa4HpMAATheeseguy1/19/2019  EuQM5S_MwhqQZPGa4HpMAA
# 46347  EuQM5S_MwhqQZPGa4HpMAAGoodfood,2/24/2019  EuQM5S_MwhqQZPGa4HpMAA
# 46348  EuQM5S_MwhqQZPGa4HpMAAVerygoodc1/14/2019  EuQM5S_MwhqQZPGa4HpMAA
# 46349  EuQM5S_MwhqQZPGa4HpMAAGreatelpa2/24/2019  EuQM5S_MwhqQZPGa4HpMAA
# 51532   EuQM5S_MwhqQZPGa4HpMAATherefood8/3/2019  EuQM5S_MwhqQZPGa4HpMAA
# 64748  EuQM5S_MwhqQZPGa4HpMAANastyavoc6/14/2019  EuQM5S_MwhqQZPGa4HpMAA
#
#        rating       date                                             review
# ...

# %%
df_reviews = pd.DataFrame(df[['review', 'review_id', 'date']])
df_reviews

# %%
from textblob import TextBlob
df = oo[oo.business_id == 'EuQM5S_MwhqQZPGa4HpMAA']

df0= pd.DataFrame(df_reviews)
#for index, row in df_reviews.iterrows():
 #   print(row)
  #  sentiment = TextBlob(row[''])
     #print each sen
df0['polarity'] = df0.apply(lambda x: TextBlob(x['review']).sentiment.polarity, axis=1)
df0['subjectivity'] = df0.apply(lambda x: TextBlob(x['review']).sentiment.subjectivity, axis=1)
print(df0)
# Out:
#                                                   review  \
# 32100  $4.50 for a sausage breakfast burrito that was...
# 32101  Great service, great food, fair prices. Never ...
# 32102  Riveras Tacos is amazing! I always order the w...
# 32103  Best Mexican food in Long Beach and I've tried...
# 32104  Been coming here for a while ever since I move...
# 32105  Theese guys are the best been going there for ...
# 46347  Good food, great customer service. I eat here ...
# 46348  Very good ceviche, the best part was the chips...
# 46349  Great el pastor! Great prices! carne asada a l...
# 51532  There food is pretty good. You order at the wi...
# 64748  Nasty avocados..never again!!! I Was a little ...
#
#                                       review_id  polarity  subjectivity
# 32100  EuQM5S_MwhqQZPGa4HpMAA$4.50fora6/14/2019  0.355556      0.611111
# 32101  EuQM5S_MwhqQZPGa4HpMAAGreatserv9/14/2019  0.350000      0.677778
# ...

# %%
# The x in the lambda function is a row (because I set axis=1)
# Apply iterates the function accross the dataframe's rows
df_reviews['polarity'] = df_reviews.apply(lambda x: TextBlob(x['review']).sentiment.polarity, axis=1)
df_reviews['subjectivity'] = df_reviews.apply(lambda x: TextBlob(x['review']).sentiment.subjectivity, axis=1)

print(df_reviews)a
